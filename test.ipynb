# %%
from src.embeddings.modelo_texto import ModeloEmbeddingTexto
from src.embeddings.modelo_imagem import ModeloEmbeddingImagem

if __name__ == "__main__":
    modelo = ModeloEmbeddingTexto()
    texto = "Olá, como você está?"
    embedding = modelo.gerar_embedding(texto)
    print(f"Texto: {texto}")
    print(f"Embedding: {embedding}")
    print(f"Dimensão do embedding: {embedding.shape}")

    modelo_imagem = ModeloEmbeddingImagem()
    imagem = "C:/Users/rafae/Downloads/imagem.png"  # Substitua pelo caminho da sua imagem
    embedding_imagem = modelo_imagem.gerar_embedding(imagem)
    print(f"embedding_imagem: {embedding_imagem}") 
    print(f"Dimensão do embedding_imagem: {embedding_imagem.shape}")

# %%
from src.ner.ner import ModeloNER

modelo_ner = ModeloNER()
texto_ner = "\n# INSTITUICDES PESQUISA PATRoCINADO PELO CONSELHO NacIONAL DE PESQUISAS\n ALGUNS ASPECTOS DESEMPENHO DAS\n# BRASILEIRAS DE\n\n# PESQUISA\n Preparado POr Francisco Almeida Biato e Eduardo Augug to de Almeida Guimarães, IPEA . <alguns_aspectos_do_desempenho_0.png> Maio de 1971"
entidade = modelo_ner.extrair_entidades(texto_ner)
print(f"Entidade: {entidade}")

# %%
from src.ingestor.ingerir_texto import IngestorTexto

ingestor = IngestorTexto()
caminho_arquivo = "E:/IPEA/rag_publicacoes/test.json"
resultado = ingestor.processar_json(caminho_arquivo)
# Out:
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Modelo NER carregado: lfcc/bert-portuguese-ner

# %%
print(f"Resultado do processamento: {resultado[2]}")
# Out:
# Resultado do processamento: {'texto': '#acroecononico: Eduardo Felipe Ohana Coordenadoria de Saúie Sérgio Francisco Piola do Setor Esterno: Coordenadoria de Transportes Comunicacões: Sílvio Caracas de Moura Junior Norma Stenzel José Adlalberto de Paula Ferreira Aaria Lúc ia Casasanta Brüzzi Selor de Processamento de Dados:', 'embedding': [[-0.18718355894088745, 0.20798605680465698, -0.012165656313300133, 0.11262586712837219, 0.1291968822479248, -0.05151905119419098, 0.12472329288721085, -0.07711634039878845, -0.006692419294267893, 0.08876101672649384, 0.03508374094963074, 0.131029412150383, 0.030599530786275864, -0.05727968364953995, -0.14879275858402252, -0.10301642119884491, 0.0005009540473110974, 0.008207546547055244, 0.03141462802886963, 0.04131050407886505, -0.013009066693484783, -0.05306672304868698, 0.05863801762461662, 0.019587824121117592, -0.005186164751648903, 0.03556235879659653, -0.09648142009973526, -0.08716090768575668, 0.13247810304164886, 0.08682414144277573, 0.17201703786849976, 0.1079900935292244, -0.015406503342092037, 0.00977144856005907, 0.009452685713768005, -0.014637533575296402, -0.05685862898826599, 0.0426550954580307, 0.05900738015770912, -0.14099876582622528, 0.17844803631305695, 0.004661975894123316, 0.06079484894871712, 0.003920895513147116, -0.2163584679365158, 0.02125594951212406, 0.02372104488313198, -0.10731823742389679, 0.04368233308196068, 0.015551171265542507, 0.05063087120652199, 0.12023355811834335, -0.08157019317150116, -0.0866558849811554, -0.025190133601427078, -0.09602698683738708, -0.0389801524579525, -0.0857737734913826, 0.03759069740772247, 0.016441548243165016, -0.01689780317246914, -0.06602640450000763, 0.001843746518716216, -0.08042226731777191, -0.09641116112470627, -0.12311557680368423, -0.07799012213945389, -0.05214076116681099, -0.0419025793671608, 0.052200641483068466, 0.15343934297561646, 0.13548262417316437, -0.03795240446925163, 0.20728738605976105, -0.03445617854595184, 0.04155728220939636, -0.031853608787059784, -0.023411903530359268, 0.04209349304437637, -0.004500736482441425, 0.12901683151721954, 0.21442988514900208, -0.055262964218854904, 0.16814005374908447, -0.16236837208271027, 0.12082155793905258, -0.05339633300900459, -0.058155108243227005, 0.05552911013364792, -0.05595356225967407, 0.012683634646236897, -0.03121103160083294, -0.029939360916614532, 0.02423146739602089, 0.021285871043801308, -0.07071903347969055, 0.10336373746395111, -0.035758938640356064, -0.025857960805296898, 0.04586775228381157, -0.11757616698741913, 0.02321106195449829, 0.06788584589958191, 0.048372525721788406, 0.06641815602779388, 0.06551308929920197, -0.03106638789176941, -0.053019993007183075, -0.01102534867823124, -0.04074351117014885, 0.015515269711613655, -0.03729446604847908, -0.11828874051570892, -0.058708515018224716, -0.2001509666442871, 0.020188696682453156, 0.046050556004047394, -0.1546308994293213, -0.18091586232185364, -0.12808682024478912, 0.03761264309287071, 0.025722859427332878, 0.05921493470668793, -0.04590707644820213, -0.04453261196613312, 0.11402943730354309, -0.024882812052965164, 0.09918782860040665, 0.042295098304748535, 0.1243724599480629, -0.026401571929454803, -0.11713706701993942, 0.024652445688843727, 0.11149576306343079, 0.031879667192697525, -0.07559777051210403, 0.06681431084871292, -0.22743730247020721, 0.1487969309091568, -0.16740478575229645, -0.02964220754802227, -0.10416972637176514, -0.08646053820848465, -0.06942223757505417, 0.08495025336742401, -0.03147943690419197, 0.04598896577954292, -0.07373039424419403, -0.04125409945845604, -0.004716997966170311, 0.08034529536962509, -0.05043719336390495, -0.057846780866384506, -0.016259094700217247, -0.03644109144806862, 0.09286824613809586, -0.03534018248319626, 0.0005055085057392716, -0.006959628313779831, 0.11569015681743622, -0.11299435049295425, 0.1062193289399147, -0.13149671256542206, 0.01889537274837494, 0.08171550929546356, 0.13645879924297333, 0.07004167884588242, -0.04092973843216896, 0.00540632940 ...
