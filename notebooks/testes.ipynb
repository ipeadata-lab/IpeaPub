# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.ingestor.ingerir_texto import IngestorTexto
from src.ingestor.ingerir_imagem import IngestorImagem
from src.ingestor.ingerir_tabela import IngestorTabela
from src.vector_db.chroma_client import ChromaDB
from src.embeddings.modelo_texto import ModeloEmbeddingTexto
from src.embeddings.modelo_imagem import ModeloEmbeddingImagem

ingestor_texto = IngestorTexto()
ingestor_imagem = IngestorImagem()
ingestor_tabela = IngestorTabela()
#modelo = ModeloEmbeddingTexto()
#modelo_imagem = ModeloEmbeddingImagem()

arquivo = "../data/aspectos_do_planejamento_orcamento_dos_estados_rio_grande_do_sul.json"

# %%
documentos_textos = ingestor_texto.processar_json(arquivo)
documentos_imagens = ingestor_imagem.processar_json(arquivo)
documentos_tabelas = ingestor_tabela.processar_json(arquivo)

# %%
chroma = ChromaDB()

for documento in documentos_textos:
    chroma.inserir_documento(documento)

for documento in documentos_imagens:
    chroma.inserir_imagem(documento)

for documento in documentos_tabelas:
    chroma.inserir_tabela(documento)

# %%
consultar_rag(pergunta)

# %%
from src.main import consultar_rag, ingerir_dados
pergunta = "Quais são as prioridades do projeto Rio Grande durante 1971 e 1974?"
ingerir_dados()
# Out:
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cpu
# Modelo NER carregado: lfcc/bert-portuguese-ner
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# c:\ProgramData\anaconda3\envs\ipea\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in D:\Users\B19943781742\.cache\huggingface\hub\models--Salesforce--blip-image-captioning-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# model.safetensors:  48%|####7     | 398M/832M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 3
#       1 from src.main import consultar_rag, ingerir_dados
#       2 pergunta = "Quais são as prioridades do projeto Rio Grande durante 1971 e 1974?"
# ----> 3 ingerir_dados()
#
# File \\storage6\usuarios\CGDTI\IpeaDataLab\projetos\RAG_PUBL\rag_publicacoes\src\main.py:21, in ingerir_dados(dir)
#      13 """
#      14 Ingerir dados de texto, imagem e tabela a partir de diretórios especificados.
#      15
#    (...)     18     imagens_dir: Diretório onde as imagens estão localizadas.
#      19 """
#      20 ingestor_texto = IngestorTexto()
# ---> 21 ingestor_imagem = IngestorImagem()
#      22 ingestor_tabela = IngestorTabela()
#      24 # Inicializar banco de dados vetorial
#
# File \\storage6\usuarios\CGDTI\IpeaDataLab\projetos\RAG_PUBL\rag_publicacoes\src\ingestor\ingerir_imagem.py:16, in IngestorImagem.__init__(self)
#      14 def __init__(self):
#      15     self.processador = AutoProcessor.from_pretrained(MODELO_VLM)
# ---> 16     self.legendar = AutoModelForImageTextToText.from_pretrained(MODELO_VLM)
#      17     self.dispositivo = "cuda" if torch.cuda.is_available() else "cpu"
#      18     self.legendar.to(self.dispositivo)
#
# File c:\ProgramData\anaconda3\envs\ipea\Lib\site-packages\transformers\models\auto\auto_factory.py:571, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     569     if model_class.config_class == config.sub_configs.get("text_config", None):
#     570         config = config.get_text_config()
# --> 571     return model_class.from_pretrained(
#     572         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     573     )
#     574 raise ValueError(
#     575     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     576     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     577 )
#
# File c:\ProgramData\anaconda3\envs\ipea\Lib\site-packages\transformers\modeling_utils.py:279, in restore_default_torch_dtype.<locals>._wrapper(*args, **kwargs)
#     277 old_dtype = torch.get_default_dtype()
#     278 try:
# --> 279     return func(*args, **kwargs)
#     280 finally:
#     281     torch.set_default_dtype(old_dtype)
#
# File c:\ProgramData\anaconda3\envs\ipea\Lib\site-packages\transformers\modeling_utils.py:4260, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, weights_only, *model_args, **kwargs)
#    4250 if (
#    4251     gguf_file
#    4252     and device_map is not None
#    4253     and ((isinstance(device_map, dict) and "disk" in device_map.values()) or "disk" in device_map)
#    4254 ):
#    4255     raise RuntimeError(
#    4256         "One or more modules is configured to be mapped to disk. Disk offload is not supported for models "
#    4257         "loaded from GGUF files."
#    4258     )
# -> 4260 checkpoint_files, sharded_metadata = _get_resolved_checkpoint_files(
#    4261     pretrained_model_name_or_path=pretrained_model_name_or_path,
#    4262     subfolder=subfolder,
#    4263     variant=variant,
#    4264     gguf_file=gguf_file,
#    4265     from_tf=from_tf,
#    4266     from_flax=from_flax,
#    4267     use_safetensors=use_safetensors,
#    4268     cache_dir=cache_dir,
#    4269     force_download=force_download,
#    4270     proxies=proxies,
#    4271     local_files_only=local_files_only,
#    4272     token=token,
#    4273     user_agent=user_agent,
#    4274     revision=revision,
#    4275     commit_hash=commit_hash,
#    4276 )
#    4278 is_sharded = sharded_metadata is not None
#    4279 is_quantized = hf_quantizer is not None
#
# File c:\ProgramData\anaconda3\envs\ipea\Lib\site-packages\transformers\modeling_utils.py:1080, in _get_resolved_checkpoint_files(pretrained_model_name_or_path, subfolder, variant, gguf_file, from_tf, from_flax, use_safetensors, cache_dir, force_download, proxies, local_files_only, token, user_agent, revision, commit_hash)
#    1072 has_file_kwargs = {
#    1073     "revision": revision,
#    1074     "proxies": proxies,
#    (...)   1077     "local_files_only": local_files_only,
#    1078 }
#    1079 if has_file(pretrained_model_name_or_path, TF2_WEIGHTS_NAME, **has_file_kwargs):
# -> 1080     raise EnvironmentError(
#    1081         f"{pretrained_model_name_or_path} does not appear to have a file named"
#    1082         f" {_add_variant(WEIGHTS_NAME, variant)} but there is a file for TensorFlow weights."
#    1083         " Use `from_tf=True` to load this model from those weights."
#    1084     )
#    1085 elif has_file(pretrained_model_name_or_path, FLAX_WEIGHTS_NAME, **has_file_kwargs):
#    1086     raise EnvironmentError(
#    1087         f"{pretrained_model_name_or_path} does not appear to have a file named"
#    1088         f" {_add_variant(WEIGHTS_NAME, variant)} but there is a file for Flax weights. Use"
#    1089         " `from_flax=True` to load this model from those weights."
#    1090     )
#
# OSError: Salesforce/blip-image-captioning-base does not appear to have a file named pytorch_model.bin but there is a file for TensorFlow weights. Use `from_tf=True` to load this model from those weights.
