# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.ingestor.ingerir_texto import IngestorTexto
from src.ingestor.ingerir_imagem import IngestorImagem
from src.ingestor.ingerir_tabela import IngestorTabela
from src.vector_db.chroma_client import ChromaDB
from src.embeddings.modelo_texto import ModeloEmbeddingTexto
from src.embeddings.modelo_imagem import ModeloEmbeddingImagem

ingestor_texto = IngestorTexto()
ingestor_imagem = IngestorImagem()
ingestor_tabela = IngestorTabela()
#modelo = ModeloEmbeddingTexto()
#modelo_imagem = ModeloEmbeddingImagem()

arquivo = "../data/aspectos_do_planejamento_orcamento_dos_estados_rio_grande_do_sul.json"

# %%
documentos_textos = ingestor_texto.processar_json(arquivo)
documentos_imagens = ingestor_imagem.processar_json(arquivo)
documentos_tabelas = ingestor_tabela.processar_json(arquivo)

# %%
chroma = ChromaDB()

for documento in documentos_textos:
    chroma.inserir_documento(documento)

for documento in documentos_imagens:
    chroma.inserir_imagem(documento)

for documento in documentos_tabelas:
    chroma.inserir_tabela(documento)

# %%
from src.main import consultar_rag, ingerir_dados
pergunta = "Quuis são as prioridades do projeto Rio Grande durante 1971 e 1974?"
ingerir_dados()
# Out:
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Modelo de embedding de imagem carregado: openai/clip-vit-base-patch16
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
# Modelo VLM carregado no dispositivo cuda: microsoft/git-base
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
#
# Processando textos dos arquivos...
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Inserindo documentos no banco de dados...
# Textos processados em 29.04 segundos.
#
# Processando imagens dos arquivos...
# Inserindo documentos de imagem no banco vetorial...
# Imagens processadas em 11.49 segundos.
#
# Processando tabelas dos arquivos...
# Inserindo documentos de tabela no banco vetorial...
# Tabelas processadas em 19.19 segundos.
#
# Ingestão de dados concluída!

# %%
consultar_rag(pergunta)
# Out:
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Modelo de embedding de imagem carregado: openai/clip-vit-base-patch16
#
# Resultados da consulta:
# Erro ao conectar com o modelo de linguagem: HTTPSConnectionPool(host='ollama-api.ipea.gov.br', port=443): Max retries exceeded with url: /api/generate (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001AF7D633260>: Failed to resolve 'ollama-api.ipea.gov.br' ([Errno 11001] getaddrinfo failed)"))
#
# Resultados relevantes:
# 1. [TABLE] Fonte: Algumas_implicações_nafta.json, Score: 8.2607
# 2. [TABLE] Fonte: Algumas_implicações_nafta.json, Score: 8.0889
# 3. [TABLE] Fonte: Algumas_implicações_nafta.json, Score: 8.0685
# 4. [TABLE] Fonte: Algumas_implicações_nafta.json, Score: 7.9524
# 5. [TABLE] Fonte: Algumas_implicações_nafta.json, Score: 7.6746
# 6. [TEXT] Fonte: Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json, Score: 4.9258
# 7. [TEXT] Fonte: Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json, Score: 4.9162
# 8. [TEXT] Fonte: Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json, Score: 4.8722
# 9. [TEXT] Fonte: Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json, Score: 4.8506
# 10. [TEXT] Fonte: Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json, Score: 4.7863
# 11. [IMAGE] Fonte: alguns_aspectos_do_desempenho.json, Score: 1.5427
# 12. [IMAGE] Fonte: Algumas_implicações_nafta.json, Score: 1.5193
# 13. [IMAGE] Fonte: Algumas_implicações_nafta.json, Score: 1.4770
# 14. [IMAGE] Fonte: Algumas_implicações_nafta.json, Score: 1.4675
# 15. [IMAGE] Fonte: Algumas_implicações_nafta.json, Score: 1.4555
# {'resposta': 'Erro ao conectar com o modelo de linguagem: HTTPSConnectionPool(host=\'ollama-api.ipea.gov.br\', port=443): Max retries exceeded with url: /api/generate (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001AF7D633260>: Failed to resolve \'ollama-api.ipea.gov.br\' ([Errno 11001] getaddrinfo failed)"))',
#  'contexto': [{'distancia': 8.260655403137207,
#    'metadados': {'entidades': "{'Data': ['1994']}",
#     'page': 188,
#     'content_type': 'table',
#     'references': '[]',
#     'footnotes': '[]',
#     'table_id': 156,
#     'title': 'None',
#     'filename': 'Algumas_implicações_nafta.json',
#     'format': 'PDF 1.6',
#     'modDate': "D:20240207182002-03'00'",
#     'self_ref': '#/tables/155',
#     'caption': ''},
#    'texto': '| (USSmil)                                           | (USSmil)                                                      | (USSmil)                                           | (USSmil)                                           |\n|----------------------------------------------------|---------------------------------------------------------------|----------------------------------------------------|----------------------------------------------------|\n| 199:J-1994                                         | 199:J-1994                                                    | 199:J-1994                                         | 199:J-1994                                         |\n| Produtos emque o Brasil aumentou sua participação  | Produtos emque o Brasil aumentou sua participação             | Produtos emque o Brasil aumentou sua participação  | Produtos emque o Brasil aumentou sua participação  |\n| Produto                                            | Descrição                                                     | Valor do ganho                                     | %ganho total                                       |\n| 8514                                               | Calçados compalasde couronatural, artificial ou regenerado    | 1.272.696,00                                       | 14.21                                              |\n| 711                                                | Café semtostar, descafeinado ounão: casca de café             | 436.693,00                                         | 4,88                                               |\n| 7843                                               | Outraspartes e peças e acessórios dos veículos automotores    | 337.073,00                                         | 3.76                                               |\n| 3341                                               | Gasolina para motores e outros óleos ligeiros                 | 295.233,00                                         | 3, 30                                              |\n| 9310                                               | Operações e mercadoriasnão dassificadas segundosua natureza   | 283.445,00                                         | 3,17                                               |\n| Produtosem que o Brasil perdeu participação        | Produtosem que o Brasil perdeu participação                   | Produtosem que o Brasil perdeu participação        | Produtosem que o Brasil perdeu participação        |\n| Produto                                            | Descrição                                                     | Valor da perda                                     | %perdatotal                                        |\n| 7642                                               | Microfones e seus suportes                                    | -1.556.180.76                                      | 21,17                                              |\n| 7648                                               | Equipamentode telecomunicações, n.e.p                         | -797.738,19                                        | 10,85                                              |\n| 7851                                               | Motocicletas e velocípedes. com motor wxiliar                 | -529.522,12                                        | 7 )fJ                                              |\n| 8131                                               | Lâmpadas eacessórios deiluminação                             | -508.010,60                                        | 6,91                                               |\n| 6794                                               | Canos. rubos e perftS de ferro ou aço                         | -456.111.88                                        | 6,21                                               |\n| 1995-1998                                          | 1995-1998                                                     | 1995-1998                  ...
#    'tipo': 'table'},
#   {'distancia': 8.08887767791748,
#    'metadados': {'format': 'PDF 1.6',
#     'references': '[]',
#     'filename': 'Algumas_implicações_nafta.json',
#     'table_id': 190,
#     'caption': '',
#     'entidades': "{'Local': ['México']}",
#     'content_type': 'table',
#     'modDate': "D:20240207182002-03'00'",
#     'self_ref': '#/tables/189',
#     'footnotes': '[]',
#     'page': 220,
#     'title': 'None'},
#    'texto': '| Produto   | A Ganho do México   | B Perda do Brasil   | e Total de ganhos   | B*(A/C)- Perda do Brasil para o México   | %Perda total   |\n|-----------|---------------------|---------------------|---------------------|------------------------------------------|----------------|\n| 8994      | 758,00              | ·2.670,21           | 50.693.208,60       | -0,04                                    | 0,00           |\n| 6291      | 1.087,00            | -1.027,75           | 50.693.208,60       | -0,02                                    | 0,00           |\n| 6618      | 15.916,00           | -55,96              | 50.693.208,60       | -0,02                                    | 0,00           |\n| 6713      | 50,00               | -13.803,40          | 50.693.208,60       | -0,01                                    | 0,00           |\n| 7622      | 704,00              | -869,11             | 50.693.208,60       | -0,01                                    | 0,00           |\n| 8469      | 1.687,00            | -358,63             | 50.693.208,60       | -0,01                                    | 0,00           |\n| 7412      | 4.629,00            | -81,23              | 50,693.208,60       | -0,01                                    | 0,00           |\n| 7248      | 689,00              | -538.41             | 50.693.208,60       | -0,01                                    | 0,00           |\n| 6525      | 16,00               | -22.357,37          | 50.693.208,60       | -0,01                                    | 0,00           |\n| 6�5       | 13,00               | -25.526,27          | 50.693.208,60       | -0,01                                    | 0,00           |\n| 6117      | 486,00              | -554,83             | 50.693.208,60       | -0,01                                    | 0,00           |\n| 7164      | 242,00              | -925,59             | 50.693.208,60       | -0,00                                    | 0,00           |\n| 5259      | 11,00               | -19.176,29          | 50.693.208,60       | -0,00                                    | 0,00           |\n| 5984      | 10,00               | -19.516,25          | 50.693.208,60       | -0,00                                    | 0,00           |\n| 6536      | 9.414,00            | -18,23              | 50.693.208,60       | -0,00                                    | 0,00           |\n| 5813      | 62.00               | -2.594,23           | 50.693.208,60       | -0,00                                    | 0,00           |\n| <Xi19     | 2.863.00            | ·53,78              | 50.693.208,60       | -0,00                                    | 0,00           |\n| 8951      | 95,00               | -1.446,16           | 50.693.208,60       | -0,00                                    | 0,00           |\n| 5791      | 731,00              | -173,45             | 50.693.208,60       | -0,00                                    | 0,00           |\n| Cll13     | 9,00                | -11.140,86          | 50.693.208,60       | -0,00                                    | 0,00           |\n| 6592      | 190,00              | -499,76             | 50.693.208,60       | -0,00                                    | 0,00           |\n| 2683      | 11,00               | -7,186,44           | 50.693.208,60       | -0,00                                    | 0,00           |\n| 2671      | 46,00               | -1.709,00           | 50.693.208,60       | -0,00                                    | 0,00           |\n| <Xi12     | 72.00               | -897,33             | 50.693.208,60       | -0,00                                    | 0,00           |\n| m1        | 53,00               | -1.001,06           | 50.693.208,60       | -0,00                                    | 0,00           |\n| 6578      | 173,00              | -297,39             | 50.693.208,60       | -0,00                                    | 0,00           |\n| 5238      | 104,00              | -48 ...
#    'tipo': 'table'},
#   {'distancia': 8.068479537963867,
#    'metadados': {'content_type': 'table',
#     'caption': '',
#     'references': '[]',
#     'format': 'PDF 1.6',
#     'modDate': "D:20240207182002-03'00'",
#     'title': 'None',
#     'page': 221,
#     'self_ref': '#/tables/190',
#     'footnotes': '[]',
#     'table_id': 191,
#     'filename': 'Algumas_implicações_nafta.json',
#     'entidades': "{'Local': ['México']}"},
#    'tipo': 'table'},
#   {'distancia': 4.925826549530029,
#    'metadados': {'format': 'PDF 1.5',
#     'title': 'None',
#     'page_number': 68,
#     'chunk_id': 1,
#     'content_type': 'text',
#     'modDate': 'D:20240528172716Z',
#     'entidades': "{'Local': ['São Gabriel', 'Santana do Livramnento', 'São Pedro do Sul', 'são Francisco de As sis', 'Rio Grande do Sul', 'Júlio de Castilhos', 'São Vicente do Sul', 'Uruguaiana', 'Alegrete']}",
#     'filename': 'Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json'},
#    'texto': "# PROJETO SUDOESTE 1\n Neste Projeto cujos objetivos principais são prono ver O desenvolvimento agrícola e 0 aproveitamento recursos rais da região sudoeste do Rio Grande do Sul foram aplicados no periodo Çr$ 5 , 3 milhões, de total previsto de Cr$ 8 , 8 milhões Es ses recursos foram destinados manutenção das unidades operacionais de Alegrete' Santana do Livramnento e Júlio de Castilhos , e à implan das uinidades de São Gabriel. Uruguaiana, são Francisco de As sis, São Vicente do Sul e São Pedro do Sul_ de natu tação",
#    'tipo': 'text'},
#   {'distancia': 4.916204929351807,
#    'metadados': {'content_type': 'text',
#     'format': 'PDF 1.5',
#     'filename': 'Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json',
#     'title': 'None',
#     'modDate': 'D:20240528172716Z',
#     'entidades': "{'Data': ['1976'], 'Local': ['Inha', 'Pernanbuco', 'RURALNORTE', 'Rio Grande do Norte', 'Massangano', 'Sergipe', 'Vale do nhas', 'Serra do Mel', 'Serra', 'Maranhão', 'Lagoas do Piauí', 'Alto Turi', 'Lagoa do Boqueirão', 'Tourão']}",
#     'page_number': 28,
#     'chunk_id': 1},
#    'texto': '- As realizações do Programa 0 final de 1976 , en volveram a execução dos seguintes projetos; PDRIs do Vale do nhas (Paraíba) da Serra do Ibiapaba (Ceará) RURALNORTE , Vilas Ru rais e Lagoa do Boqueirão (Rio Grande do Norte) do Agreste Meridio nal (Pernanbuco) projetos de irrigações do Baixo São Francisco lagoas e Sergipe) do Vale do Jaíba(Minas Gerais) Tourão (Bahia) Massangano (Banhia) Lagoas do Piauí (Piauí); e projetos de nização dos rios Corrente e são Francisco (Bahia) Serra do Mel e Lagoa do Boqueirão (Rio Grande do Norte) dentre outros. Pira\n Ainda em 1976 foram aprovados e postos em implanta ção 05 projetos de desenvolvimento rural integrado-PDRIs do Baixo Parnaíba (Maranhão) da Serra (Ceará) Sertões de Inha muns e Salgado (Ceará) da Serra do Triunfo (Pernambuco) Colônia do Pindorama (Alagoas) Tabuleiros Costeiros (Sergipe) _ dentro tros, al:m do projeto de coloni do Alto Turi (Maranhão) zação',
#    'tipo': 'text'},
#   {'distancia': 4.872165679931641,
#    'metadados': {'content_type': 'text',
#     'modDate': 'D:20240528172716Z',
#     'filename': 'Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json',
#     'title': 'None',
#     'page_number': 41,
#     'chunk_id': 1,
#     'format': 'PDF 1.5'},
#    'texto': 'tanas Região Metropolitana do Recife: conclusãö sobre as bacias de drenagem dos rios Beberibe, Setú bal e Jordão , do plano diretor de preservação ambiental urbana vi sando a preservar monumentos histórico-culturais; em andamento estudo de caracterização das unidades especiais de planejamento; em elaboração 05 . termos de referência para 0 plano diretor de resíduos solidos drenagem e recursos hfdricos. Metropolitana de Salvador: em mento 0 estudo do uso do solo , com participação GEIPOT , CNPU BNH Governo do Estado e SUDENE ; celebração de convênio para do plano diretor de residuos sólidos _ Região anda elabe ração Região Metropolitana de Fortaleza: em ela boração 0 plano diretor de drenagem fluvial e 0 plano glcbal de e ocupação do solo; em conclusão O plano diretor de assentamentos residenciais Desenvolvimento Integrado das Capitais Centros Dinamizadores e Cidades do Interior do Nordeste Conclusão da pesquisa sobre custos de urbanização no Nordeste e em fase de conclusão 0 estudo',
#    'tipo': 'text'},
#   {'distancia': 4.850584983825684,
#    'metadados': {'page_number': 81,
#     'modDate': 'D:20240528172716Z',
#     'format': 'PDF 1.5',
#     'entidades': "{'Local': ['Rio de Janeiro', 'Itaguai', 'Maricá']}",
#     'filename': 'Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json',
#     'chunk_id': 2,
#     'content_type': 'text',
#     'title': 'None'},
#    'texto': 'perifêricos_ que ainda pro liferam impulsionados pelo forte desenvolvimento econônico na re gião. ações pela urba s6 des Região Metropolitana do Rio de Janeiro A Região Metropolitana do Rio de Janeiro teve suas diretrizes definidas no I? PLANRIO . Programaram-se grandes inves timentos para 05 Municipios de Itaguai e Maricá_ ao nesmo tempo em sa0 orientados 0s investimentos em infra-estrutura {em espe cial, saneamento) municlpios limitrofes do Rio de Janeiro cando reduzir 0 desnível de equipamento entre 0 município capital e demais. Foi aprovado (Exposição de Motivos n? 342/76) pro grama de investinentos no valor de Cr$ 200 milhões com recursos da Unlão que vem somar-se aos investimentos do Estado dirigidos ba sicamente à periferia metropolitana Serviços como segurança blica, estão sendo contemplados em função ãe sua carência. que bus 4 FUNDREM técnico da preconi zando uma efetlva de controle dos investimentos estaduais, região ação',
#    'tipo': 'text'},
#   {'distancia': 4.786277770996094,
#    'metadados': {'title': 'None',
#     'format': 'PDF 1.5',
#     'entidades': "{'Local': ['Pilão Arca do', 'Sento Sé', 'Renanso', 'Sobradinho', 'Itaparica']}",
#     'filename': 'Acompanhamento_do_II_PND_exercicio_de_1976_desenvolvimento_regional_e_urbano.json',
#     'modDate': 'D:20240528172716Z',
#     'chunk_id': 0,
#     'page_number': 39,
#     'content_type': 'text'},
#    'texto': "# Usina Hidrelétrica de Sobradinho\n Realização de obras no sistema de navegação , na ragem , na tomada d'água, nos diques e no sistema extravasor; cons trução das novas sedes municipais de Renanso , Sento Sé e Pilão Arca do ; conclusão dos projetos de reassentamento daš populações rurais; construção das Variantes da estrada BR-235 ; conclusão do desvio do rio; prosseguimento das obras de aterro concretagem e bar\n# Usina Hidrelétrica\n Em fase de exploração preliminar _ procedendo-se à coleta de dados necessários ao anteprojeto (estudos topogrâficos sondagens geológicas, levantanentos aerofotogrametricos) além de estudos alternativos nivel de lay-out' para cada ua das 3 alternativas selecionadas para 0 eixo da barragem; (a execução da bra foi postergada em vista da prioridade conferida à construção da usina de Itaparica)\n# Usina Hidreletrica de Itaparica",
#    'tipo': 'text'},
#   {'distancia': 1.542665958404541,
#    'metadados': {'content_type': 'image',
#     'page': 1,
#     'image_id': 1,
#     'caption': ' Legenda: the writing is in black',
#     'modDate': "D:20250113143601-03'00'",
#     'classification': "['logo']",
#     'title': 'None',
#     'confidence': 0.9989573955535888,
#     'filename': 'alguns_aspectos_do_desempenho.json',
#     'footnotes': '[]',
#     'self_ref': '#/pictures/0',
#     'format': 'PDF 1.6',
#     'ref': 'alguns_aspectos_do_desempenho_0.png',
#     'references': '[]'},
#    'texto': 'Legenda: the writing is in black',
#    'tipo': 'image',
#    'caminho_imagem': 'alguns_aspectos_do_desempenho_0.png'},
#   {'distancia': 1.519298791885376,
#    'metadados': {'ref': 'Algumas_implicações_nafta_3.png',
#     'modDate': "D:20240207182002-03'00'",
#     'footnotes': '[]',
#     'filename': 'Algumas_implicações_nafta.json',
#     'image_id': 4,
#     'content_type': 'image',
#     'page': 5,
#     'format': 'PDF 1.6',
#     'caption': ' Legenda: letter on the sign',
#     'title': 'None',
#     'references': '[]',
#     'classification': "['logo']",
#     'self_ref': '#/pictures/3',
#     'confidence': 0.9997033476829528},
#    'texto': 'Legenda: letter on the sign',
#    'tipo': 'image',
#    'caminho_imagem': 'Algumas_implicações_nafta_3.png'},
#   {'distancia': 1.477039098739624,
#    'metadados': {'ref': 'Algumas_implicações_nafta_0.png',
#     'page': 1,
#     'references': '[]',
#     'footnotes': '[]',
#     'classification': "['line_chart']",
#     'title': 'None',
#     'confidence': 0.9522916078567504,
#     'format': 'PDF 1.6',
#     'filename': 'Algumas_implicações_nafta.json',
#     'caption': ' Legenda: a graph showing a line graph and a line graph.',
#     'content_type': 'image',
#     'image_id': 1,
#     'modDate': "D:20240207182002-03'00'",
#     'self_ref': '#/pictures/0'},
#    'texto': 'Legenda: a graph showing a line graph and a line graph.',
#    'tipo': 'image',
#    'caminho_imagem': 'Algumas_implicações_nafta_0.png'},
#   {'distancia': 1.4674606323242188,
#    'metadados': {'ref': 'Algumas_implicações_nafta_8.png',
#     'page': 6,
#     'caption': ' Legenda: white print style letter',
#     'content_type': 'image',
#     'footnotes': '[]',
#     'image_id': 9,
#     'modDate': "D:20240207182002-03'00'",
#     'self_ref': '#/pictures/8',
#     'filename': 'Algumas_implicações_nafta.json',
#     'references': '[]',
#     'confidence': 0.9995444416999816,
#     'title': 'None',
#     'format': 'PDF 1.6',
#     'classification': "['logo']"},
#    'texto': 'Legenda: white print style letter',
#    'tipo': 'image',
#    'caminho_imagem': 'Algumas_implicações_nafta_8.png'},
#   {'distancia': 1.4555306434631348,
#    'metadados': {'image_id': 10,
#     'confidence': 0.9999921321868896,
#     'format': 'PDF 1.6',
#     'classification': "['bar_chart']",
#     'modDate': "D:20240207182002-03'00'",
#     'filename': 'Algumas_implicações_nafta.json',
#     'content_type': 'image',
#     'ref': 'Algumas_implicações_nafta_9.png',
#     'page': 41,
#     'caption': 'GRÁFICO Importações dos Estados Unidos 1995/1998  Legenda: figure is described in the surrounding text.',
#     'title': 'None',
#     'footnotes': '[]',
#     'self_ref': '#/pictures/9',
#     'references': '[]'},
#    'texto': 'Legenda: figure is described in the surrounding text.',
#    'tipo': 'image',
#    'caminho_imagem': 'Algumas_implicações_nafta_9.png'}]}
