# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.ingestor.ingerir_texto import IngestorTexto
from src.ingestor.ingerir_imagem import IngestorImagem
from src.ingestor.ingerir_tabela import IngestorTabela
from src.vector_db.chroma_client import ChromaDB
from src.embeddings.modelo_texto import ModeloEmbeddingTexto
from src.embeddings.modelo_imagem import ModeloEmbeddingImagem

ingestor_texto = IngestorTexto()
ingestor_imagem = IngestorImagem()
ingestor_tabela = IngestorTabela()
modelo = ModeloEmbeddingTexto()
modelo_imagem = ModeloEmbeddingImagem()
chroma = ChromaDB()

arquivo = "data/aspectos_do_planejamento_orcamento_dos_estados_rio_grande_do_sul.json"

# %%
documentos_textos = ingestor_texto.processar_json(arquivo)
documentos_imagens = ingestor_imagem.processar_json(arquivo)
documentos_tabelas = ingestor_tabela.processar_json(arquivo)

# %%
for documento in documentos_textos:
    chroma.inserir_documento(documento)

for documento in documentos_imagens:
    chroma.inserir_imagem(documento)

for documento in documentos_tabelas:
    chroma.inserir_tabela(documento)

# %%
from src.main import consultar_rag, ingerir_dados
pergunta = "Quuais são as prioridades do projeto Rio Grande durante 1971 e 1974?"
ingerir_dados()
# Out:
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Modelo de embedding de imagem carregado: openai/clip-vit-base-patch16
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
# Modelo VLM carregado no dispositivo cuda: microsoft/git-base
# Modelo de embedding de texto carregado: sentence-transformers/paraphrase-multilingual-mpnet-base-v2
# Device set to use cuda:0
# Modelo NER carregado: lfcc/bert-portuguese-ner
#
# Processando textos dos arquivos...
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Erro ao extrair entidades: The size of tensor a (537) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (520) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (553) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (676) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (569) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (567) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (541) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (546) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (548) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (517) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (532) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (538) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (537) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (537) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (537) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (541) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (547) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (529) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (529) must match the size of tensor b (512) at non-singleton dimension 1
# Erro ao extrair entidades: The size of tensor a (530) must match the size of tensor b (512) at non-singleton dimension 1
#
# Processando imagens dos arquivos...
